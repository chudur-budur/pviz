# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import os

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D

plt.rcParams.update({'figure.max_open_warning': 0})

# %%
sys.path.append('../')
from vis.utils import io

fpath = "../data/dtlz2-nbi/8d/dataf.csv"
refpath = "../data/dtlz2/8d/dataf.csv"
reflayerpath = "../data/dtlz2/8d/depth-cont-cvhull.csv"

F = np.loadtxt(fpath, delimiter=',')
R = np.loadtxt(refpath, delimiter=',')
L = io.loadtxt(reflayerpath, delimiter=',', dtype=int)

print(F.shape)
print(R.shape)
print(L.shape)


fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(F[:,0], F[:,1], F[:,2], s=1)
plt.show()
# Out:
# (3432, 8)
# (4000, 8)
# (6,)
